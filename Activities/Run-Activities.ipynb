# %%
import pandas as pd

ds = pd.read_csv('activities.csv')
ds
# Out:
#      Activity ID                Activity Name  Description  \
# 0     2284658991  Freiburg im Breisgau Laufen          NaN
# 1     2284658936  Freiburg im Breisgau Laufen          NaN
# 2     2228102647  Freiburg im Breisgau Laufen          NaN
# 3     2104984694  Freiburg im Breisgau Laufen          NaN
# 4     2084195352  Freiburg im Breisgau Laufen          NaN
# ..           ...                          ...          ...
# 150   1205026379  Freiburg im Breisgau Laufen          NaN
# 151   1203784563  Freiburg im Breisgau Laufen          NaN
# 152    912662907  Freiburg im Breisgau Laufen          NaN
# 153    908332579               Waldspielplatz          NaN
# 154   1199436564  Freiburg im Breisgau Laufen          NaN
#
#             Begin Timestamp  Begin Timestamp (Raw Milliseconds)  \
# 0     Sa, Nov 4, 2017 12:07                       1509793643000
# 1      Fr, Nov 3, 2017 9:47                       1509698845000
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 47 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Activity ID                            155 non-null    int64
#  1   Activity Name                          155 non-null    object
#  2   Description                            0 non-null      float64
#  3   Begin Timestamp                        155 non-null    object
#  4   Begin Timestamp (Raw Milliseconds)     155 non-null    int64
#  5   End Timestamp                          155 non-null    object
#  6   End Timestamp (Raw Milliseconds)       155 non-null    int64
#  7   Device                                 155 non-null    object
#  8   Activity Parent                        155 non-null    object
#  9   Activity Type                          155 non-null    object
# ...
